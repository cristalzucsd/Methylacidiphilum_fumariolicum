# %% [markdown]
# ## 2.4 Model Validation and application
# ### 2.4.3 Heterotrophic metabolism is redox-limited
# **Figure 5**
#
# This notebook recreates the analyses and figures from section 2.4.3. Flux sampling of the model[1] using Methane, Propane, Isopropanol and Acetone. This analysis is divided in two notebooks, one dedicated to performing the simulations and other dedicted to plotting and data analysis (This).
#
# The notebook is divided in three sections:
# 1. Summary of reactions with significant changes [1]
# 3. Summary of the Top 20 reactions ranked by PageRank Centrality [2]
#
# [1] Megchelenbrink W, Huynen M, Marchiori E (2014) optGpSampler: An Improved Tool for Uniformly Sampling the Solution-Space of Genome-Scale Metabolic Networks. PLoS ONE 9(2): e86587. https://doi.org/10.1371/journal.pone.0086587
#
# [2] Beguerisse-Díaz, M., Bosque, G., Oyarzún, D. et al. Flux-dependent graphs for metabolic networks. npj Syst Biol Appl 4, 32 (2018). https://doi.org/10.1038/s41540-018-0067-y

# %%
# Set up the modeling environment
from plotly.subplots import make_subplots
from tqdm import tqdm

import plotly.graph_objects as go
import plotly.express as pl
import plotly.io as pio

import pandas as pd
import numpy as np
import json

# Load style and theme templates for the figures
with open('theme_template.json', 'r') as template:
    style = json.load(template)
style["layout"]["height"] = 70 * (600 / 158.75)
style["layout"]["width"] = 160 * (600 / 158.75)

pio.templates["paper"] = go.layout.Template(
    data=style["data"],
    layout=style["layout"]
)
pio.templates.default = "simple_white+paper"

# Load Simulation results
summary_tests = {}
for substrate in ["Propane", "Isopropanol", "Acetone"]:
    summary_tests[substrate] = pd.read_excel(
        "data_files/summary_sampling.xlsx", sheet_name=substrate, index_col="Unnamed: 0"
    )
    
pagerank = {}
for substrate in ["Methane", "Propane", "Isopropanol", "Acetone"]:
    pagerank[substrate]= pd.read_csv(f"data_files/pagerank_{substrate}.csv")
    pagerank[substrate].drop(columns="Unnamed: 0", inplace=True)

# Dataframe used to group reactions by pathway
rxn_colors = pd.read_csv("data_files/reaction_pathways.csv", index_col="rxn_id", sep="\t")

# Model in table format
model_csv = pd.read_excel("../model_files/iMFP2023.xls", sheet_name="reactions", index_col="rxn_id")

# %% [markdown]
# ## Section 1
# ---
#
# Summary of reactions with significant changes

# %%
logf_cutoff = 0.5
cutoff = 0.2

# Identify significant flux changes in each condition
diff_propane_ks = set(summary_tests["Propane"].query("abs(log2F)>@logf_cutoff").query("kstest>@cutoff").index)
diff_propanol_ks = set(summary_tests["Isopropanol"].query("abs(log2F)>@logf_cutoff").query("kstest>@cutoff").index)
diff_acetone_ks = set(summary_tests["Acetone"].query("abs(log2F)>@logf_cutoff").query("kstest>@cutoff").index)

# Merge all significant reactions from the three conditions
significant_rxns = diff_propane_ks.union(diff_propanol_ks).union(diff_acetone_ks)

# Remove exchange and transport reactions from the list of significant reactions
false_positives = ['2PPOHtex', 'ACETONEtex', 'C3H8tex', 'CH4tex', 'EX_2ppoh_e',
                   'N2tex_r', 'N2trpp', 'NIT1c', 'EX_acetone_e', 'MTHGXLtabcpp',
                   'NITR_NOpp', 'NO2tpp', 'NO3t7p', 'NORpp', 'EX_c3h8_e',
                   "ACtex_r", "HAO2pp", "SUCCtex", 'EX_h2o_e',
                   'FALDtpp', "H2Otex", 'EX_o2_e', 'O2tex', 'FACOAL120t2pp',
                   'EX_for_e','FORtex', 'PPA', 'H2Otpp', "FALDHpp", "FALTHFL",
                   'N2Otex', 'EX_n2o_e', 'EX_ac_e', 'EX_etoh_e', 'ACtex', 'ETOHtrpp', 
                   'DM_cyt554red_p', 'EX_succ_e', 'NOtex', 'SUCCt1pp', 'EX_no_e', 'SK_cyt554oxi_p',
                   'ETOHtex']

for id in false_positives:
    if id in significant_rxns:
        significant_rxns.remove(id)
significant_rxns = set(significant_rxns)
not_significant_rxns = ~summary_tests[substrate].index.isin(significant_rxns)

# %%
# Use this command to explore significant reactions in each condition
summary_tests["Propane"].loc[significant_rxns, ["median", "log2F"]].join(model_csv.loc[:, "Reaction"]).join(rxn_colors.iloc[:, 2])
# Out:
#                 median     log2F  \
# ABTA      4.956195e-02  1.509419
# ACALD    -3.622609e-02  4.535168
# ACGAM6PS  6.528248e-04  0.735769
# ACGAMPM   6.528248e-04  0.735769
# ACGK      8.694103e-03  0.970456
# ...                ...       ...
# TKT2     -1.435128e-01 -1.709869
# TPI       3.616199e-01 -1.476210
# TRDR      3.715255e-02  1.327938
# UMPK      5.673511e-02  0.758469
# UPPN      6.918232e-07  0.998321
#
#                                                    Reaction  \
# ABTA                4abut_c + akg_c <=> glu__L_c + sucsal_c
# ACALD     accoa_c + h_c + nadh_c <=> acald_c + coa_c + n...
# ACGAM6PS      accoa_c + gam6p_c --> acgam6p_c + coa_c + h_c
# ACGAMPM                             acgam6p_c --> acgam1p_c
# ACGK                    acglu_c + atp_c --> acg5p_c + adp_c
# ...                                                     ...
# TKT2                  e4p_c + xu5p__D_c <=> f6p_B_c + g3p_c
# TPI                                        g3p_c <=> dhap_c
# TRDR           h_c + nadph_c + trdox_c --> nadp_c + trdrd_c
# UMPK                        atp_c + ump_c --> adp_c + udp_c
# UPPN      cala_c + h2o_c + 2.0 h_c --> ala_B_c + co2_c +...
#
#                                  Level_1
# ABTA                     Acid Resistance
# ACALD                       Fermentation
# ACGAM6PS       Carbohydrate Biosynthesis
# ACGAMPM        Carbohydrate Biosynthesis
# ACGK             Amino Acid Biosynthesis
# ...                                  ...
# TKT2                                 PPP
# TPI                           Glycolysis
# TRDR                  Other Biosynthesis
# UMPK      Nucleotides/sides Biosynthesis
# UPPN       Nucleotides/sides Degradation
#
# [180 rows x 4 columns]

# %%
# Volcano plots
# Set a color for each pathway
rxn_colors = rxn_colors.loc[significant_rxns]
colorway = style["layout"]["colorway"]
color_pathway = dict(
    zip(rxn_colors["Level_0"].unique(), colorway)
)

# Set the color to each reaction based on the pathway
for id in rxn_colors.index:
    pathway = rxn_colors.loc[id, "Level_0"]
    rxn_colors.loc[id, "color"] = color_pathway[pathway]

styling = {
    "Propane": {"color": "#B82E2E", "symbol": "diamond"},
    "Isopropanol": {"color": "#66AA00", "symbol": "square"},
    "Acetone": {"color": "#DD4477", "symbol": "x"}
}

sum_pathways = {}
fig_sampling = {}
for substrate in ["Propane", "Isopropanol", "Acetone"]:
    
    # Create a figure object
    fig_sampling[substrate] = make_subplots(rows=1, cols=2)
    # Create a dataframe to store log2 FC values by pathway
    sum_pathways[substrate] = pd.DataFrame()
    
    # Recover significant reactions
    log2F_significant = summary_tests[substrate].query("log2F>-6").query("abs(log2F)>@logf_cutoff").query("kstest>@cutoff")["log2F"]
    kstest_significant = summary_tests[substrate].query("log2F>-6").query("abs(log2F)>@logf_cutoff").query("kstest>@cutoff")["kstest"]
    
    for id in log2F_significant.index:
        if "EX_" not in id:
            if id not in false_positives:
                
                # Plot each reaction
                fig_sampling[substrate].add_trace(
                    go.Scatter(
                        x=[log2F_significant[id]],
                        y=[kstest_significant[id]],
                        mode="markers", name=substrate, showlegend=False,
                        marker={"color": rxn_colors.loc[id, "color"],
                                "symbol": styling[substrate]["symbol"],
                                "line": {"width": 0.5, "color": "rgb(0,0,0)"}},
                        text=[id]
                    ),
                    row=1, col=1
                )
                
                # Acumulator of log2 FC by pathway
                try:
                    sum_pathways[substrate].loc[rxn_colors.loc[id, "Level_1"], "sum"] += log2F_significant[id]
                except KeyError:
                    sum_pathways[substrate].loc[rxn_colors.loc[id, "Level_1"], "sum"] = log2F_significant[id]
    
    # Recover non-significant reactions
    log2F = summary_tests[substrate].query("log2F>-6").query("abs(log2F)<@logf_cutoff").query("kstest<@cutoff")["log2F"]
    kstest = summary_tests[substrate].query("log2F>-6").query("abs(log2F)<@logf_cutoff").query("kstest<@cutoff")["kstest"]
    
    # Plot non-significant reactions
    fig_sampling[substrate].add_trace(
        go.Scatter(
            x=log2F,
            y=kstest,
            mode="markers", name=substrate, showlegend=False,
            marker={"color": "rgb(0,0,0)", "symbol": styling[substrate]["symbol"]},
        ),
        row=1, col=1
    )

    # Bar plot of log2 FC by pathway
    sum_pathways[substrate].sort_values("sum", ascending=True, inplace=True)
    sum_pathways[substrate] = sum_pathways[substrate].join(pd.DataFrame(color_pathway, index=["color"]).transpose())
    for path in sum_pathways[substrate].index:
        fig_sampling[substrate].add_trace(
            go.Bar(
                x=[sum_pathways[substrate].loc[path, "sum"]], y=[path], orientation="h",
                marker={"color": sum_pathways[substrate].loc[path, "color"]}, showlegend=False
            ),
            row=1, col=2
        )
    
    # Figure styling
    fig_sampling[substrate].update_yaxes(
        title_text="KS-value",
        row=1, col=1
    )
    fig_sampling[substrate].update_xaxes(
        title_text="log2 FC",
        row=1, col=1
    )
    fig_sampling[substrate].update_yaxes(
        side="right",
        tickfont_size= 10,
        row=1, col=2
    )
    fig_sampling[substrate].update_xaxes(
        title_text="sum(log2 FC)",
        range= [-15, 15],
        row=1, col=2
    )
    fig_sampling[substrate].show()
# Out:
# <div>                            <div id="76360796-23af-4a9a-b41f-9123829fd407" class="plotly-graph-div" style="height:264.56692913385825px; width:604.7244094488188px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76360796-23af-4a9a-b41f-9123829fd407")) {                    Plotly.newPlot(                        "76360796-23af-4a9a-b41f-9123829fd407",                        [{"marker":{"color":"rgb(17,119,51)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["NTRIR2x"],"x":[2.35038653809744],"y":[0.44],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(255,255,179)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["DAPOPc"],"x":[-1.0],"y":[0.96],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(202,178,214)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["SUCOAS"],"x":[1.1898288543978],"y":[0.35],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(202,178,214)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["MDH"],"x":[0.635719999275276],"y":[0.37],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(56,166,165)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["SBP"],"x":[-1.741957832146033],"y":[0.57],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(146,209,209)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["FBA3"],"x":[-1.741957832146033],"y":[0.57],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(166,206,227)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["GLYCL"],"x":[4.633459580507973],"y":[1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(49,99,149)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["DCTPD"],"x":[-0.7087812609546111],"y":[0.33],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(202,178,214)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["ICL"],"x":[0.6758041765362596],"y":[0.21],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(56,166,165)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["RBPC"],"x":[-3.199959277363577],"y":[0.98],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(253,191,111)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["PPNCL3"],"x":[0.9029246142771294],"y":[0.22],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(56,166,165)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["GAPDy"],"x":[-2.091712656216277],"y":[0.95],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(209,118,31)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["DURIPP"],"x":[0.7807364096964896],"y":[0.28],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(255,255,179)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"diamond"},"mode":"markers","name":"Propane","showlegend":false,"text":["GLYCLTDy"],"x":[0.8414386830295203],"y":[0.23],"type":"scatter","xaxis":"x","yaxis": ...
# <div>                            <div id="31eb1ac2-4244-4ac2-9cf7-5d1f5ce5c821" class="plotly-graph-div" style="height:264.56692913385825px; width:604.7244094488188px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31eb1ac2-4244-4ac2-9cf7-5d1f5ce5c821")) {                    Plotly.newPlot(                        "31eb1ac2-4244-4ac2-9cf7-5d1f5ce5c821",                        [{"marker":{"color":"rgb(17,119,51)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["NTRIR2x"],"x":[2.289782247301052],"y":[0.42],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(255,255,179)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["DAPOPc"],"x":[-1.0],"y":[0.96],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(202,178,214)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["SUCOAS"],"x":[1.702753269631314],"y":[0.44],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(202,178,214)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["MDH"],"x":[0.746760077442963],"y":[0.43],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(56,166,165)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["SBP"],"x":[-1.055979186553807],"y":[0.49],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(146,209,209)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["FBA3"],"x":[-1.055979186553807],"y":[0.49],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(184,46,46)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["PC1MT"],"x":[1.911946141598799],"y":[0.34],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(184,46,46)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["SAMU3_1"],"x":[1.911946141598799],"y":[0.34],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(166,206,227)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["H4THDPRx"],"x":[1.056054570231982],"y":[0.33],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(253,191,111)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["THD2pp"],"x":[-0.6542590252302706],"y":[0.24],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(166,206,227)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["GLYCL"],"x":[4.439114192549193],"y":[1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(56,166,165)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["RBPC"],"x":[-2.976271783871391],"y":[0.96],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(177,89,40)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["EAR60x"],"x":[0.6463275289698719],"y":[0.34],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(253,191,111)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"square"},"mode":"markers","name":"Isopropanol","showlegend":false,"text":["PPNCL3"],"x":[0.6777601139440427],"y" ...
# <div>                            <div id="6acd43ab-ca3f-4d2a-878f-1976a515ddb3" class="plotly-graph-div" style="height:264.56692913385825px; width:604.7244094488188px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6acd43ab-ca3f-4d2a-878f-1976a515ddb3")) {                    Plotly.newPlot(                        "6acd43ab-ca3f-4d2a-878f-1976a515ddb3",                        [{"marker":{"color":"rgb(17,119,51)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["NTRIR2x"],"x":[1.85262237493069],"y":[0.37],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(255,255,179)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["DAPOPc"],"x":[-1.0],"y":[0.96],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(253,191,111)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["PPNCL2"],"x":[-0.6515112772299075],"y":[0.34],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(202,178,214)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["SUCOAS"],"x":[1.394343048590932],"y":[0.33],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(202,178,214)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["MDH"],"x":[0.7805398728837052],"y":[0.41],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(56,166,165)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["SBP"],"x":[-1.710831051875788],"y":[0.54],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(146,209,209)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["FBA3"],"x":[-1.710831051875788],"y":[0.54],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(17,119,51)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["PPCK"],"x":[1.064686226326465],"y":[0.3],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(184,46,46)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["PC1MT"],"x":[1.502555241015656],"y":[0.44],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(184,46,46)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["SAMU3_1"],"x":[1.502555241015656],"y":[0.44],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(166,206,227)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["H4THDPR"],"x":[0.8097474495890497],"y":[0.37],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(253,191,111)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["THD2pp"],"x":[-1.127248410102995],"y":[0.32],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(166,206,227)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["GLYCL"],"x":[4.594557584223647],"y":[1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(49,99,149)","line":{"color":"rgb(0,0,0)","width":0.5},"symbol":"x"},"mode":"markers","name":"Acetone","showlegend":false,"text":["DCTPD"],"x":[1.095984746331909],"y":[0.27],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(202,178,214)","line":{"color":"rgb(0,0,0)","width":0.5}," ...

# %% [markdown]
# ## Section 2
# ---
#
# Plot of most central reactions

# %%
# Remove Exchanges and transport reactions
false_positives = ['2PPOHtex', 'ACETONEtex', 'C3H8tex', 'CH4tex', 'MEOHDHpp', "EX_co2_e", "PPA",
                   "C3H8OXq8", "IPPOHDHpp", "atpm", "CO2tpp_r", "H2Otex_r", "CO2tex_r", "ATPS1",
                   'NITR_NOpp', 'NO2tpp', 'NO3t7p', 'NORpp', 'PMMOipp', "ACTNMOq8", "H2Otpp_r",
                   "ACtex_r", "SUCCtex", 'EX_h2o_e', 'ACOHDHpp', 'MTHGXLtabcpp', "BIOMASS_Mfumariolicum_Pic",
                   'MDH', 'FALDtpp', 'ACOHDHpp', "H2Otex", "NDPK7", "RNDR3", 'EX_o2_e', "EX_h_e"]

# Recover PageRank values for top 20 reactions
no_top_rxns = 20
substrate = "Propane"
top_reactions = pagerank[substrate].drop(columns=false_positives).mean(0).sort_values(ascending=False).head(no_top_rxns).index

# Pre-process dataset in the format requered for plotting functions
top_pagerank = pd.DataFrame()
for substrate in ["Methane", "Propane", "Isopropanol", "Acetone"]:
    for id in tqdm(top_reactions):
        tmp = pd.DataFrame(pagerank[substrate][id].to_list(), columns=["PR-Centrality"])
        tmp.loc[:, "Substrate"] = substrate
        tmp.loc[:, "Reaction"] = id
        top_pagerank = top_pagerank.append(tmp)

# Draw figure
fig_prcentrality = pl.box(top_pagerank, y="PR-Centrality", x="Reaction", color="Substrate", points=False)
fig_prcentrality.update_layout(
    {"yaxis": {"title": {"text": "PR-Centrality"},
               "tickfont": {"size": 14},
               "range": [-0.01, 0.15]},
     "xaxis": {"tickfont": {"size": 14},
               "tickangle": 20,
               "title": {"font": {"size": 14}}
               },
     "height": 100 * (600 / 158.75),
     "width": 250 * (600 / 158.75),
     "legend": {"title": {"text": None},
                "font": {"size": 14},
                "x": 1, "y": 1}
     }
)
fig_prcentrality.show()
# Out:
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 747.37it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 611.12it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 794.05it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 741.19it/s]
# <div>                            <div id="1b531732-7968-49c1-a3af-2e7036a0dc9d" class="plotly-graph-div" style="height:377.9527559055118px; width:944.8818897637796px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b531732-7968-49c1-a3af-2e7036a0dc9d")) {                    Plotly.newPlot(                        "1b531732-7968-49c1-a3af-2e7036a0dc9d",                        [{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Substrate=Methane\u003cbr\u003eReaction=%{x}\u003cbr\u003ePR-Centrality=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Methane","marker":{"color":"rgb(49,99,149)"},"name":"Methane","notched":false,"offsetgroup":"Methane","orientation":"v","showlegend":true,"x":["CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","CYTCBB3pp1","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","NADH16pp","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO1_KT","CYO ...
